# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %%
{train,test}.ds_info = tfds.load('food101', split=['train', 'validation'], as_supervised=True, with_info=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3525120857.py in <cell line: 0>()
# ----> 1 {train,test}.ds_info = tfds.load('food101', split=['train', 'validation'], as_supervised=True, with_info=True)
#
# NameError: name 'train' is not defined
