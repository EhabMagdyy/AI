# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
import os
# Out:
# 2026-03-15 13:55:02.920625: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tapakah68/supervisely-filtered-segmentation-person-dataset")

print("Path to dataset files:", path)
# Out:
# ...
#   1%|          | 30.0M/4.31G [01:11<2:52:53, 443kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("tapakah68/supervisely-filtered-segmentation-person-dataset")
#       6 print("Path to dataset files:", path)
#
# File ~/.local/lib/python3.10/site-packages/kagglehub/datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# ...

# %%
import os

xtrain_path = os.path.join(path, "xtrain")
ytrain_path = os.path.join(path, "ytrain")

xtest_path = os.path.join(path, "xtest")
ytest_path = os.path.join(path, "ytest")

# %%
import cv2
import numpy as np

IMG_SIZE = 128

def load_dataset(img_dir, mask_dir):
    images = []
    masks = []

    img_files = sorted(os.listdir(img_dir))
    mask_files = sorted(os.listdir(mask_dir))

    for img, mask in zip(img_files, mask_files):

        img_path = os.path.join(img_dir, img)
        mask_path = os.path.join(mask_dir, mask)

        image = cv2.imread(img_path)
        image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))

        mask = cv2.imread(mask_path, 0)
        mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))

        images.append(image)
        masks.append(mask)

    images = np.array(images) / 255.0
    masks = np.array(masks) / 255.0
    masks = np.expand_dims(masks, axis=-1)

    return images, masks
